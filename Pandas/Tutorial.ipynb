# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_rows',500)
pd.set_option('display.max_columns',20)

# %%
names = ["age","workclass","fnlwgt","education","education-num","marital-status","occupation","relationship","race",
         "sex","capital-gain","capital-loss","hours-per-week","native-country",'target']

# %%
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data',names=names)

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'target'],
#       dtype='object')

# %%
df.values
# Out:
# array([[39, ' State-gov', 77516, ..., 40, ' United-States', ' <=50K'],
#        [50, ' Self-emp-not-inc', 83311, ..., 13, ' United-States',
#         ' <=50K'],
#        [38, ' Private', 215646, ..., 40, ' United-States', ' <=50K'],
#        ...,
#        [58, ' Private', 151910, ..., 40, ' United-States', ' <=50K'],
#        [22, ' Private', 201490, ..., 20, ' United-States', ' <=50K'],
#        [52, ' Self-emp-inc', 287927, ..., 40, ' United-States', ' >50K']],
#       dtype=object)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=32561, step=1)

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  target          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.head(2)
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
#
#         marital-status        occupation    relationship    race    sex  \
# 0        Never-married      Adm-clerical   Not-in-family   White   Male
# 1   Married-civ-spouse   Exec-managerial         Husband   White   Male
#
#    capital-gain  capital-loss  hours-per-week  native-country  target
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K

# %%
df.tail()
# Out:
#        age      workclass  fnlwgt    education  education-num  \
# 32556   27        Private  257302   Assoc-acdm             12
# 32557   40        Private  154374      HS-grad              9
# 32558   58        Private  151910      HS-grad              9
# 32559   22        Private  201490      HS-grad              9
# 32560   52   Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation relationship    race      sex  \
# 32556   Married-civ-spouse        Tech-support         Wife   White   Female
# 32557   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 32558              Widowed        Adm-clerical    Unmarried   White   Female
# 32559        Never-married        Adm-clerical    Own-child   White     Male
# 32560   Married-civ-spouse     Exec-managerial         Wife   White   Female
#
#        capital-gain  capital-loss  hours-per-week  native-country  target
# ...

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df['race'].value_counts()
# Out:
#  White                 27816
#  Black                  3124
#  Asian-Pac-Islander     1039
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name: race, dtype: int64

# %%
df.corr()
# Out:
#                      age    fnlwgt  education-num  capital-gain  capital-loss  \
# age             1.000000 -0.076646       0.036527      0.077674      0.057775
# fnlwgt         -0.076646  1.000000      -0.043195      0.000432     -0.010252
# education-num   0.036527 -0.043195       1.000000      0.122630      0.079923
# capital-gain    0.077674  0.000432       0.122630      1.000000     -0.031615
# capital-loss    0.057775 -0.010252       0.079923     -0.031615      1.000000
# hours-per-week  0.068756 -0.018768       0.148123      0.078409      0.054256
#
#                 hours-per-week
# age                   0.068756
# fnlwgt               -0.018768
# education-num         0.148123
# capital-gain          0.078409
# capital-loss          0.054256
# hours-per-week        1.000000

# %%
sns.heatmap(df.corr(),annot=True,cmap='rainbow')

# %%
df['age'].empty
# Out:
# False

# %%
df.isnull().any().any()
# Out:
# False

# %%
df.isna().any().any()
# Out:
# False

# %%
any(df['age']<0)
# Out:
# False

# %%
any(df['age']==0)
# Out:
# False

# %%
#Rename
#Replace


df['new_variable'] = 5

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  target  five
# ...

# %%
df['sex'].replace(to_replace=' Female',value='Woman')
# Out:
# 0         Male
# 1         Male
# 2         Male
# 3         Male
# 4        Woman
#          ...
# 32556    Woman
# 32557     Male
# 32558    Woman
# 32559     Male
# 32560    Woman
# Name: sex, Length: 32561, dtype: object

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'target', 'five'],
#       dtype='object')

# %%
subset = df[['age','workclass', 'fnlwgt', 'education', 'education-num']]

# %%
subset.head()
# Out:
#    age          workclass  fnlwgt   education  education-num
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13

# %%
#.loc
#.iloc

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'target', 'five'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week     five
# count    32561.000000  32561.0
# mean        40.437456      5.0
# std         12.347429      0.0
# min          1.000000      5.0
# 25%         40.000000      5.0
# 50%         40.000000      5.0
# 75%         45.000000      5.0
# ...

# %%
df.loc[(df['age']>35) & (df['sex']==' Male') & (df['capital-gain']>50_000),
       ['age','sex','workclass', 'capital-gain', 'education', 'education-num']]
# Out:
#        age    sex      workclass  capital-gain     education  education-num
# 1246    54   Male   Self-emp-inc         99999   Prof-school             15
# 1368    52   Male        Private         99999       HS-grad              9
# 1482    53   Male   Self-emp-inc         99999       HS-grad              9
# 1528    52   Male        Private         99999     Bachelors             13
# 1616    46   Male        Private         99999   Prof-school             15
# ...    ...    ...            ...           ...           ...            ...
# 31828   47   Male        Private         99999       Masters             14
# 31972   43   Male   Self-emp-inc         99999   Prof-school             15
# 32090   66   Male        Private         99999     Bachelors             13
# 32238   47   Male        Private         99999   Prof-school             15
# 32518   57   Male      Local-gov         99999       HS-grad              9
#
# [117 rows x 6 columns]

# %%
1_000_000_000
# Out:
# 1000000000

# %%
1000000000
# Out:
# 1000000000

# %%
df.iloc[0:100 , 0:3]
# Out:
#     age          workclass  fnlwgt
# 0    39          State-gov   77516
# 1    50   Self-emp-not-inc   83311
# 2    38            Private  215646
# 3    53            Private  234721
# 4    28            Private  338409
# ..  ...                ...     ...
# 95   29          Local-gov  115585
# 96   48   Self-emp-not-inc  191277
# 97   37            Private  202683
# 98   48            Private  171095
# 99   32        Federal-gov  249409
#
# [100 rows x 3 columns]

# %%
#Dataframe

series1 = pd.Series([1,2,3,4,5])
series2 = pd.Series(['one','two','three','four','five'])

# %%
df_small = pd.DataFrame({'numbers': series1,
             'string_numbers': series2})

# %%
df_small
# Out:
#    numbers string_numbers
# 0        1            one
# 1        2            two
# 2        3          three
# 3        4           four
# 4        5           five

# %%
df_slice1 = df.iloc[0:100,:]
df_slice2 = df.iloc[100:200,:]

# %%
print(df_slice1.shape,df_slice2.shape)
# Out:
# (100, 16) (100, 16)

# %%
concated = pd.concat([df_slice1,df_slice2])

# %%
concated.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  target  five
# ...

# %%
concated.shape
# Out:
# (200, 16)

# %%
df_join1 = df.iloc[0:100,0:5]
df_join2 = df.iloc[0:100,5:10]

# %%
df_join1.head()
# Out:
#    age          workclass  fnlwgt   education  education-num
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13

# %%
df_join2.head()
# Out:
#         marital-status          occupation    relationship    race      sex
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female

# %%
joined = df_join1.join(df_join2)

# %%
concated
# Out:
#      age          workclass  fnlwgt      education  education-num  \
# 0     39          State-gov   77516      Bachelors             13
# 1     50   Self-emp-not-inc   83311      Bachelors             13
# 2     38            Private  215646        HS-grad              9
# 3     53            Private  234721           11th              7
# 4     28            Private  338409      Bachelors             13
# 5     37            Private  284582        Masters             14
# 6     49            Private  160187            9th              5
# 7     52   Self-emp-not-inc  209642        HS-grad              9
# 8     31            Private   45781        Masters             14
# 9     42            Private  159449      Bachelors             13
# 10    37            Private  280464   Some-college             10
# 11    30          State-gov  141297      Bachelors             13
# 12    23            Private  122272      Bachelors             13
# ...

# %%
df['age'].skew()
# Out:
# 0.5587433694130484

# %%
#Visualize

# %%
df['age'].hist(bins=20)

# %%
df['age'].hist(bins=20, by=df['sex'], figsize=(12,6), color='red', sharey=True)
plt.show()

# %%
df[(df['age']>18)].iloc[0:5000].plot(kind='scatter',
                                                   x='age',
                                                   y='hours-per-week')

# %%
missings = pd.DataFrame({'col1': [1,1,3,np.nan,3,6,np.nan,8],
                        'col2':[1,1,3,8,3,4,3,np.nan]})

# %%
missings
# Out:
#    col1  col2
# 0   1.0   1.0
# 1   1.0   1.0
# 2   3.0   3.0
# 3   NaN   8.0
# 4   3.0   3.0
# 5   6.0   4.0
# 6   NaN   3.0
# 7   8.0   NaN

# %%
missings['col1'].mean()
# Out:
# 3.6666666666666665

# %%
missings.fillna(method='bfill')
# Out:
#    col1  col2
# 0   1.0   1.0
# 1   1.0   1.0
# 2   3.0   3.0
# 3   3.0   8.0
# 4   3.0   3.0
# 5   6.0   4.0
# 6   8.0   3.0
# 7   8.0   NaN

# %%
df.groupby(by='age').mean()['hours-per-week'].plot()
